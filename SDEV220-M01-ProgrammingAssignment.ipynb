# %%
print("aaaaa")
# Out:
# aaaaa

# %%
seconds_per_hour = 60*60 #3.1/3.2
seconds_per_day = seconds_per_hour*24 # 3.3/3.4
print(str(seconds_per_day/seconds_per_hour)) #3.5
print(str(seconds_per_day//seconds_per_hour)) # 3.6
# Out:
# 24.0
# 24
