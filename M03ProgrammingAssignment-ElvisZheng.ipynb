# %%
#7.4
#7.5: Yes, the spelling of the string changed
#7.6
#7.7
things = ["MOZZERELLA", "Cinderella"]
for i in things:
    print (i)
# Out:
# MOZZERELLA
# Cinderella

# %%
#9.1
def good():
    characters = ["Harry", "Ron", "Hermione"]
    return characters

#9.2
def get_odds():
    odds = []
    for i in range(10):
        if(i%2==1):
            odds.append(i)
    return odds

for i in range(len(get_odds())):
    if(i == 3):
        print(get_odds()[i-1])
# Out:
# 5
